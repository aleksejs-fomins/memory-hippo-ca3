# %%
# Import libraries from outside folder
import sys
sys.path.append('../lib/')

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from single_population_discrete import SinglePopulationDiscrete
from plots_lib import subplots1D

# %load_ext autoreload

# %%
# Load raw images
# img1 = (mpimg.imread('../img/cat3.png')[:,:,0] > 0.5).astype(int)
# img2 = (mpimg.imread('../img/mouse3.png')[:,:,0] > 0.5).astype(int)
img1 = mpimg.imread('../img/cat4.png')
img2 = mpimg.imread('../img/mouse4.png')

# Plot raw images
fig, axis = plt.subplots(ncols=2)
axis[0].imshow(img1, cmap='gray')
axis[1].imshow(img2, cmap='gray')
axis[0].set_axis_off()
axis[1].set_axis_off()
plt.suptitle('Original Images');

# %%
############################################
# Initialize a network with no synapses
############################################
N_NEURON = img1.shape[0] * img1.shape[1]
print('Number of neurons is', N_NEURON)

param = {
    'N_EXC' : N_NEURON,
    'N_INH' : 0,

    'T_RANGE_EXC' : [0.0, 1.0],
    'T_RANGE_INH' : [0.0, 1.0],
    
    'IP_RATE_EXC' : 0.01,
    'IP_RATE_INH' : 0.01,
    'V_EQ_EXC' : 0.5,
    'V_EQ_INH' : 0.5,

    'WITH_SYNAPSES' : False
}

spd1 = SinglePopulationDiscrete(param)


############################################
# Run the network with no input, only noise
############################################
VI_MAT_NOISE = np.zeros((200, N_NEURON))

param_sim_noise = {
    'WITH_IP'        : True,
    'WITH_SP'        : False,
    'SOMA_NOISE_EXC' : [0.0, 0.5],
    'SOMA_NOISE_INH' : [0.0, 0.5]
}

spd1.run(VI_MAT_NOISE, param_sim_noise)

# Plot network indicators
plotStruct = np.array([
    [['V_EXC', 'V_INH'], ['DV_EXC', 'DV_INH']],
    [['T_EXC', 'T_INH'], ['DT_EXC', 'DT_INH']]
#     [['W_EXC_EXC', 'W_EXC_INH', 'W_INH_EXC', 'W_INH_INH'],
#     ['DW_EXC_EXC', 'DW_EXC_INH', 'DW_INH_EXC', 'DW_INH_INH']]
])

subplots1D(spd1.statsDict, plotStruct)
# Out:
# Number of neurons is 6400
# Doing step 0 {'State': 0, 'IP': 0, 'STDP': 0, 'STAT': 0, 'UPDATE': 0}
# Doing step 20 {'State': 0.01, 'IP': 0.0, 'STDP': 0, 'STAT': 0.0, 'UPDATE': 0.0}
# Doing step 40 {'State': 0.01, 'IP': 0.0, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 60 {'State': 0.02, 'IP': 0.0, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 80 {'State': 0.02, 'IP': 0.0, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 100 {'State': 0.03, 'IP': 0.0, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 120 {'State': 0.04, 'IP': 0.0, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 140 {'State': 0.04, 'IP': 0.01, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 160 {'State': 0.05, 'IP': 0.01, 'STDP': 0, 'STAT': 0.02, 'UPDATE': 0.0}
# Doing step 180 {'State': 0.06, 'IP': 0.01, 'STDP': 0, 'STAT': 0.02, 'UPDATE': 0.0}

# %%
############################################
# Run the network by feeding in the cat 100 times
############################################
VI_MAT_CAT = np.tile(np.ndarray.flatten(img1), (200, 1))

param_sim_img = {
    'WITH_IP'       : True,
    'WITH_SP'       : False,
    'SOMA_NOISE_EXC' : [0.0, 0.1],
    'SOMA_NOISE_INH' : [0.0, 0.1]
}

spd1.run(VI_MAT_CAT, param_sim_img)

subplots1D(spd1.statsDict, plotStruct)
# Out:
# Doing step 0 {'State': 0, 'IP': 0, 'STDP': 0, 'STAT': 0, 'UPDATE': 0}
# Doing step 20 {'State': 0.01, 'IP': 0.0, 'STDP': 0, 'STAT': 0.0, 'UPDATE': 0.0}
# Doing step 40 {'State': 0.01, 'IP': 0.0, 'STDP': 0, 'STAT': 0.0, 'UPDATE': 0.0}
# Doing step 60 {'State': 0.02, 'IP': 0.0, 'STDP': 0, 'STAT': 0.0, 'UPDATE': 0.0}
# Doing step 80 {'State': 0.03, 'IP': 0.0, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 100 {'State': 0.03, 'IP': 0.0, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 120 {'State': 0.04, 'IP': 0.0, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 140 {'State': 0.04, 'IP': 0.0, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 160 {'State': 0.05, 'IP': 0.01, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 180 {'State': 0.06, 'IP': 0.01, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}

# %%
fig, ax = plt.subplots(ncols=2)
ax[0].imshow(spd1.v['V_EXC'].reshape(img1.shape), cmap='gray')
ax[1].imshow(spd1.v['T_EXC'].reshape(img1.shape), cmap='gray')
plt.show()

# %%
############################################
# Show more noise, then show more 
############################################

VI_MAT_MOUSE = np.tile(np.ndarray.flatten(img2), (200, 1))

spd1.run(VI_MAT_NOISE, param_sim_noise)

subplots1D(spd1.statsDict, plotStruct)

fig, ax = plt.subplots(ncols=2)
ax[0].imshow(spd1.v['V_EXC'].reshape(img1.shape), cmap='gray')
ax[1].imshow(spd1.v['T_EXC'].reshape(img1.shape), cmap='gray')
plt.show()

spd1.run(VI_MAT_MOUSE, param_sim_img)

subplots1D(spd1.statsDict, plotStruct)

fig, ax = plt.subplots(ncols=2)
ax[0].imshow(spd1.v['V_EXC'].reshape(img1.shape), cmap='gray')
ax[1].imshow(spd1.v['T_EXC'].reshape(img1.shape), cmap='gray')
plt.show()
# Out:
# Doing step 0 {'State': 0, 'IP': 0, 'STDP': 0, 'STAT': 0, 'UPDATE': 0}
# Doing step 20 {'State': 0.01, 'IP': 0.0, 'STDP': 0, 'STAT': 0.0, 'UPDATE': 0.0}
# Doing step 40 {'State': 0.01, 'IP': 0.0, 'STDP': 0, 'STAT': 0.0, 'UPDATE': 0.0}
# Doing step 60 {'State': 0.02, 'IP': 0.0, 'STDP': 0, 'STAT': 0.0, 'UPDATE': 0.0}
# Doing step 80 {'State': 0.03, 'IP': 0.0, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 100 {'State': 0.03, 'IP': 0.0, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 120 {'State': 0.04, 'IP': 0.0, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 140 {'State': 0.04, 'IP': 0.01, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 160 {'State': 0.05, 'IP': 0.01, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 180 {'State': 0.06, 'IP': 0.01, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 0 {'State': 0, 'IP': 0, 'STDP': 0, 'STAT': 0, 'UPDATE': 0}
# Doing step 20 {'State': 0.01, 'IP': 0.0, 'STDP': 0, 'STAT': 0.0, 'UPDATE': 0.0}
# Doing step 40 {'State': 0.01, 'IP': 0.0, 'STDP': 0, 'STAT': 0.0, 'UPDATE': 0.0}
# Doing step 60 {'State': 0.02, 'IP': 0.0, 'STDP': 0, 'STAT': 0.0, 'UPDATE': 0.0}
# Doing step 80 {'State': 0.02, 'IP': 0.0, 'STDP': 0, 'STAT': 0.0, 'UPDATE': 0.0}
# Doing step 100 {'State': 0.03, 'IP': 0.0, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 120 {'State': 0.04, 'IP': 0.0, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 140 {'State': 0.04, 'IP': 0.0, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 160 {'State': 0.05, 'IP': 0.0, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
# Doing step 180 {'State': 0.05, 'IP': 0.01, 'STDP': 0, 'STAT': 0.01, 'UPDATE': 0.0}
